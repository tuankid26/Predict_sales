# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Liquor Sales Analysis/input
# Out:
# /content/drive/MyDrive/Liquor Sales Analysis/input

# %% [markdown]
# # Read Data and Cleaning Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Liquor Sales Analysis/input/Iowa_Liquor_Sales.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   Invoice/Item Number        Date  ...  Volume Sold (Liters) Volume Sold (Gallons)
# 0        S29198800001  11/20/2015  ...                  4.50                  1.19
# 1        S29195400002  11/21/2015  ...                  9.00                  2.38
# 2        S29050300001  11/16/2015  ...                  0.30                  0.08
# 3        S28867700001  11/04/2015  ...                  5.25                  1.39
# 4        S29050800001  11/17/2015  ...                  0.30                  0.08
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#          Invoice/Item Number  ... Volume Sold (Gallons)
# 12591072     INV-08368000074  ...                  0.63
# 12591073     INV-08368000075  ...                  0.39
# 12591074     INV-08368000076  ...                  0.39
# 12591075     INV-08368000077  ...                  0.39
# 12591076     INV-08368000078  ...                  0.39
#
# [5 rows x 24 columns]

# %%
df.dtypes
# Out:
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
df.nunique()
# Out:
# Invoice/Item Number      12591077
# Date                         1379
# Store Number                 1884
# Store Name                   1952
# Address                      3154
# City                          793
# Zip Code                      871
# Store Location               4477
# County Number                  99
# County                        200
# Category                      107
# Category Name                 130
# Vendor Number                 271
# Vendor Name                   393
# Item Number                  7395
# Item Description             5865
# Pack                           30
# Bottle Volume (ml)             49
# State Bottle Cost            2768
# State Bottle Retail          3224
# Bottles Sold                  450
# Sale (Dollars)              23154
# Volume Sold (Liters)         1180
# Volume Sold (Gallons)        1184
# dtype: int64

# %%
df['City'].value_counts()
# Out:
# DES MOINES      811086
# CEDAR RAPIDS    597416
# DAVENPORT       411104
# Des Moines      307692
# WATERLOO        289538
#                  ...
# Winfield            56
# ROBINS              50
# Whittemore          48
# Earling             13
# ALVORD              10
# Name: City, Length: 793, dtype: int64

# %%
df.isnull().sum()
# Out:
# Invoice/Item Number          0
# Date                         0
# Store Number                 0
# Store Name                   0
# Address                   2376
# City                      2375
# Zip Code                  2420
# Store Location            2375
# County Number            79178
# County                   79178
# Category                  8020
# Category Name            16086
# Vendor Number                3
# Vendor Name                  1
# Item Number                  0
# Item Description             0
# Pack                         0
# Bottle Volume (ml)           0
# State Bottle Cost           10
# State Bottle Retail         10
# Bottles Sold                 0
# Sale (Dollars)              10
# Volume Sold (Liters)         0
# Volume Sold (Gallons)        0
# dtype: int64

# %%
df.Date = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df['Sale (Dollars)'] = df['Sale (Dollars)'].str.replace('$','')
df['Sale (Dollars)'] = df['Sale (Dollars)'].astype('float')

# %%
df.dropna( inplace= True)

# %%
print(df['Date'].min())
print(df['Date'].max())
# Out:
# 2012-01-03 00:00:00
# 2017-10-31 00:00:00

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## Top 10 Categories of liquors that has higest sale

# %%
import plotly.express as px
import plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# %%
df_plot = df.groupby(['Category Name','Pack','Date'])['Sale (Dollars)'].sum()
df_plot = df_plot.groupby(['Category Name','Pack']).max().sort_values()
df_plot = df_plot.groupby(['Category Name']).sum().sort_values(ascending = False)

top_count = pd.DataFrame(df_plot)
top_count1 = pd.DataFrame(df_plot.head(10))
top_count_category = df_plot.head(5).index

# %%
fig_reg = px.bar(top_count1,x=top_count1.index, y='Sale (Dollars)',color='Sale (Dollars)')
fig_reg.update_layout(
    title="Sales of liquor per category",
    xaxis_title=" Category Name",
    yaxis_title="Sales in dollars",
    )
fig_reg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="582bc836-7b23-437b-a4a8-e00a833aa1d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("582bc836-7b23-437b-a4a8-e00a833aa1d3")) {
#                     Plotly.newPlot(
#                         '582bc836-7b23-437b-a4a8-e00a833aa1d3',
# ...

# %%
top_count_category_2017 = []
for i in range(2012,2018):
  df_plot = df[df['Year'] == i]
  df_plot = df_plot.groupby(['Category Name','Pack','Date'])['Sale (Dollars)'].sum().groupby(['Category Name','Pack']).max().sort_values().groupby(['Category Name']).sum().sort_values(ascending = False)

  top_count = pd.DataFrame(df_plot)
  top_count1 = pd.DataFrame(df_plot.head(10))
  if i == 2017 : top_count_category_2017 = df_plot.index
  fig_reg = px.bar(top_count1,x=top_count1.index, y='Sale (Dollars)',color='Sale (Dollars)')
  fig_reg.update_layout(
      title= "Sales of liquor per category in " + str(i),
      xaxis_title=" Category Name",
      yaxis_title="Sales in dollars",
      )
  fig_reg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eddafdfa-a1c9-4ebd-8341-22a5bf167994" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eddafdfa-a1c9-4ebd-8341-22a5bf167994")) {
#                     Plotly.newPlot(
#                         'eddafdfa-a1c9-4ebd-8341-22a5bf167994',
# ...

# %% [markdown]
# ## Sale of liquor by city name (top 20)

# %%
df_plot = df.groupby(['City','Pack','Date'])['Sale (Dollars)'].sum()
df_plot = df_plot.groupby(['City','Pack']).max().sort_values().groupby(['City']).sum().sort_values(ascending=False)
top_count1 = pd.DataFrame(df_plot)
top_count1 = pd.DataFrame(df_plot.head(20))

fig_reg = px.bar(top_count1,x=top_count1.index, y='Sale (Dollars)',color='Sale (Dollars)')
fig_reg.update_layout(
    title="Sales of liquor per city",
    xaxis_title=" City Name",
    yaxis_title="Sales in dollars",
    )
fig_reg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cfd2fdc0-173e-468c-9550-b3397d80028e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cfd2fdc0-173e-468c-9550-b3397d80028e")) {
#                     Plotly.newPlot(
#                         'cfd2fdc0-173e-468c-9550-b3397d80028e',
# ...

# %%
df_plot = df.groupby(['Month','Pack','Date'])['Sale (Dollars)'].sum().groupby(
            ['Month','Pack']).max().sort_values().groupby(
            ['Month']).sum().sort_values(ascending=False)
top_count1 = pd.DataFrame(df_plot)
top_count1 = pd.DataFrame(df_plot.head(50))

fig_reg = px.bar(top_count1,x=top_count1.index, y='Sale (Dollars)',color='Sale (Dollars)')
fig_reg.update_layout(
    title="Sales of liquor per Month",
    xaxis_title=" Month Number",
    yaxis_title="Sales in dollars",
    )
fig_reg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9646685e-c238-4aa8-af60-c7e9ce0c9891" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9646685e-c238-4aa8-af60-c7e9ce0c9891")) {
#                     Plotly.newPlot(
#                         '9646685e-c238-4aa8-af60-c7e9ce0c9891',
# ...

# %%
daily_sales = df.groupby('Date', as_index=False)['Sale (Dollars)'].sum()

# %%
daily_sales_sc = go.Scatter(x=daily_sales['Date'], y=daily_sales['Sale (Dollars)'])
layout = go.Layout(title='Daily sales', xaxis=dict(title='Date'), yaxis=dict(title='Sales'))
fig = go.Figure(data=[daily_sales_sc], layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f007e706-ee27-4e80-8aaf-3f47bccd28e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f007e706-ee27-4e80-8aaf-3f47bccd28e7")) {
#                     Plotly.newPlot(
#                         'f007e706-ee27-4e80-8aaf-3f47bccd28e7',
# ...

# %% [markdown]
# ## Sales of liquors with category and the volumne of liquor sold

# %%
df_plot = df.groupby(['Category Name','Pack','Date'])['Sale (Dollars)'].sum().groupby(
            ['Category Name','Pack']).max().sort_values().groupby(
            ['Category Name']).sum().sort_values(ascending=False)
top_count1 = pd.DataFrame(df_plot)
#top_count1 = pd.DataFrame(df_plot.head(10))

df_plot = df.groupby(['Category Name','Pack','Date'])['Volume Sold (Liters)'].sum().groupby(
            ['Category Name','Pack']).max().sort_values().groupby(
            ['Category Name']).sum().sort_values(ascending=False)
top_count2 = pd.DataFrame(df_plot)
#top_count2 = pd.DataFrame(df_plot.head(10)

# %%
top_count = pd.concat([top_count1 , top_count2],axis=1)
top_count = top_count.sort_values(['Sale (Dollars)'],ascending=False)[:10]
top_count
# Out:
#                                     Sale (Dollars)  Volume Sold (Liters)
# CANADIAN WHISKIES                        801091.72              72113.43
# DECANTERS & SPECIALTY PACKAGES           747101.19              24751.10
# SPICED RUM                               535896.54              35696.05
# VODKA 80 PROOF                           525214.85              62974.30
# TENNESSEE WHISKIES                       480247.71              17100.41
# CREAM LIQUEURS                           270950.75              11960.50
# IMPORTED VODKA                           241715.77              13911.68
# STRAIGHT BOURBON WHISKIES                217516.84              10580.84
# MISC. AMERICAN CORDIALS & LIQUEURS       217419.60              11028.25
# TEQUILA                                  203857.03              10275.24

# %%
fig = go.Figure(data=[
    go.Bar(name='sale in dollars',x=top_count.index, y=top_count['Sale (Dollars)']),
    go.Bar(name='Volume in litres',x=top_count.index, y=top_count['Volume Sold (Liters)'])
])
# Change the bar mode
fig.update_layout(barmode='group',title="Sales of liquors with category and the volume of liquor sold.",
    xaxis_title=" category",
    yaxis_title="Sale and the amount of liquor sold in litre.",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4f4b5178-658d-46a4-94d5-b0180a89bf76" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f4b5178-658d-46a4-94d5-b0180a89bf76")) {
#                     Plotly.newPlot(
#                         '4f4b5178-658d-46a4-94d5-b0180a89bf76',
# ...

# %% [markdown]
# ## Volume sold in litres by vendor name

# %%
df_plot = df.groupby(['Vendor Name','Pack','Date'])['Volume Sold (Liters)'].sum().groupby(
            ['Vendor Name','Pack']).max().sort_values().groupby(
            ['Vendor Name']).sum().sort_values(ascending=False)
top_count1 = pd.DataFrame(df_plot)
#top_count1 = pd.DataFrame(df_plot.head(50))

fig_reg = px.bar(top_count1,x=top_count1.index, y='Volume Sold (Liters)',color='Volume Sold (Liters)')
fig_reg.update_layout(
    title="Volume sold by vendor name",
    xaxis_title=" Vendor Name",
    yaxis_title="Liquor sold in Litres",
    )
fig_reg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="172bb8b1-d5b3-4d48-bfd4-95a5dfd29c1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("172bb8b1-d5b3-4d48-bfd4-95a5dfd29c1f")) {
#                     Plotly.newPlot(
#                         '172bb8b1-d5b3-4d48-bfd4-95a5dfd29c1f',
# ...

# %% [markdown]
# ## Top 10 Stores of liquors that has highest sale

# %%
df_plot = df.groupby(['Store Name','Pack','Date'])['Sale (Dollars)'].sum().groupby(
            ['Store Name','Pack']).max().sort_values().groupby(
            ['Store Name']).sum().sort_values(ascending=False)
top_count1 = pd.DataFrame(df_plot)
#top_count1 = pd.DataFrame(df_plot.head(10))

df_plot = df.groupby(['Store Name','Pack','Date'])['Volume Sold (Liters)'].sum().groupby(
            ['Store Name','Pack']).max().sort_values().groupby(
            ['Store Name']).sum().sort_values(ascending=False)
top_count2 = pd.DataFrame(df_plot)
#top_count2 = pd.DataFrame(df_plot.head(10)

# %%
top_count = pd.concat([top_count1 , top_count2],axis=1)
top_count = top_count.sort_values(['Sale (Dollars)'],ascending=False)[:10]
top_count
# Out:
#                                      Sale (Dollars)  Volume Sold (Liters)
# Costco Wholesale #788                     672122.14              32138.00
# Sam's Club 8162 / Cedar Rapids            516574.20              33972.50
# Sam's Club 6344 / Windsor Heights         467299.30              31594.50
# Sam's Club 6979 / Ankeny                  448253.22              27333.50
# Hy-Vee #3 / BDI / Des Moines              382944.34              21963.31
# Costco Wholesale #1111 / Coralville       363240.17              17150.25
# Sam's Club 8238 / Davenport               338888.35              23732.30
# Hy-Vee Wine and Spirits / Iowa City       277219.91              16985.70
# Sam's Club 4973 / Dubuque                 270983.09              17264.25
# Hy-Vee Wine and Spirits / WDM             241864.00              15687.39

# %% [markdown]
# # Data Processing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
df.drop(['Invoice/Item Number', 'Date' , 'Store Name','City', 'Address', 'Zip Code' , 'Store Location', 'County' , 'Vendor Name','Vendor Number', 'Item Description'], axis = 1,inplace = True)

# %%
df['State Bottle Cost'] = df['State Bottle Cost'].str.replace('$','')
df['State Bottle Cost'] = df['State Bottle Cost'].astype('float')

df['State Bottle Retail'] = df['State Bottle Retail'].str.replace('$','')
df['State Bottle Retail'] = df['State Bottle Retail'].astype('float')

# %%
# category_2017 = pd.DataFrame (top_count_category_2017)
category_2017.to_csv('category_2017.csv')

# %%
for i in category_2017['Category Name']:
  data = df[df['Category Name'] == i]
  row, col = data.shape 
  if row >= 100000 : data = data.tail(100000)
  x = data.drop("Sale (Dollars)",axis = 1 )
  y = data["Sale (Dollars)"]
  x = pd.DataFrame(x, columns=data.drop("Sale (Dollars)", axis=1).columns)
  y = pd.DataFrame(y, columns=["Sale (Dollars)"])
  i = ''.join(filter(str.isalnum, i))
  x.to_csv('train_'+i+'.csv')
  y.to_csv('test_'+i+'.csv')

# %%
category_2017 = pd.DataFrame (top_count_category_2017)
row,col = category_2017.shape
for i in range(0,row):
  tmp = category_2017['Category Name'][i]
  category_2017['Category Name'][i] = ''.join(filter(str.isalnum, tmp))

# %%
category_2017
# Out:
#                         Category Name
# 0                      AmericanVodkas
# 1                    CanadianWhiskies
# 2                       AmericanVodka
# 3             StraightBourbonWhiskies
# 4                           SpicedRum
# 5          TemporarySpecialtyPackages
# 6                      ImportedVodkas
# 7                      WhiskeyLiqueur
# 8                    ImportedBrandies
# 9                   TennesseeWhiskies
# 10                    100AgaveTequila
# 11              AmericanFlavoredVodka
# 12                    BlendedWhiskies
# 13                      ImportedVodka
# 14           ImportedCordialsLiqueurs
# 15              ImportedFlavoredVodka
# 16                       MixtoTequila
# 17                        FlavoredRum
# 18                      CreamLiqueurs
# 19                   AmericanSchnapps
# 20                      IrishWhiskies
# 21                           WhiteRum
# 22                   AmericanBrandies
# 23                     ScotchWhiskies
# ...

# %% [markdown]
# # Training Model RandomForest

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

result = []
for i in category_2017.head(10)['Category Name'] :
  X = pd.read_csv('train_'+ i +'.csv')
  y = pd.read_csv('test_'+ i + '.csv')

  X.drop("Unnamed: 0",axis = 1,inplace = True)
  y.drop('Unnamed: 0', axis = 1,inplace = True)

  X.drop('Category Name',axis = 1,inplace = True)

  # split train test
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

  # preparing data
  pipeline = Pipeline([
    ('std_scalar', StandardScaler())
  ])

  X_train = pipeline.fit_transform(X_train)
  X_test = pipeline.transform(X_test)
  # trainning model 
  print('Trainning Model Data ' + i )
  rf_reg = RandomForestRegressor(n_estimators=1000)
  rf_reg.fit(X_train, y_train)

  test_pred = rf_reg.predict(X_test)
  train_pred = rf_reg.predict(X_train)

  print('Test set evaluation:\n_____________________________________')
  print_evaluate(y_test, test_pred)

  print('Train set evaluation:\n_____________________________________')
  print_evaluate(y_train, train_pred)

  result.append([i, *evaluate(y_test, test_pred) ])
# Out:
# Trainning Model Data AmericanVodkas
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Test set evaluation:
# _____________________________________
# MAE: 7.698870429887665
# MSE: 408.4450914782432
# RMSE: 20.210024529382522
# R2 Square 0.8419063298253097
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 2.8669162606927596
# MSE: 57.250353323691414
# RMSE: 7.566396323461481
# R2 Square 0.9775426093703331
# __________________________________
# Trainning Model Data CanadianWhiskies
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Test set evaluation:
# ...

# %%
results_df = pd.DataFrame(data=result, columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square'])
results_df
# Out:
#                         Model        MAE          MSE       RMSE  R2 Square
# 0              AmericanVodkas   7.698870   408.445091  20.210025   0.841906
# 1            CanadianWhiskies  15.541989  1438.661131  37.929687   0.822333
# 2               AmericanVodka   7.882635   421.157696  20.522127   0.825145
# 3     StraightBourbonWhiskies  17.650775  1491.716259  38.622743   0.815839
# 4                   SpicedRum   9.736294   627.853275  25.057001   0.887472
# 5  TemporarySpecialtyPackages   0.000000     0.000000   0.000000   1.000000
# 6              ImportedVodkas  19.240336  1708.995096  41.339994   0.810427
# 7              WhiskeyLiqueur   8.680520   625.177606  25.003552   0.898968
# 8            ImportedBrandies  22.467063  3857.420513  62.108136   0.790356
# 9           TennesseeWhiskies  20.179510  2309.945112  48.061888   0.868258

# %%
results_df.drop([5])
# Out:
#                      Model        MAE          MSE       RMSE  R2 Square
# 0           AmericanVodkas   7.698870   408.445091  20.210025   0.841906
# 1         CanadianWhiskies  15.541989  1438.661131  37.929687   0.822333
# 2            AmericanVodka   7.882635   421.157696  20.522127   0.825145
# 3  StraightBourbonWhiskies  17.650775  1491.716259  38.622743   0.815839
# 4                SpicedRum   9.736294   627.853275  25.057001   0.887472
# 6           ImportedVodkas  19.240336  1708.995096  41.339994   0.810427
# 7           WhiskeyLiqueur   8.680520   625.177606  25.003552   0.898968
# 8         ImportedBrandies  22.467063  3857.420513  62.108136   0.790356
# 9        TennesseeWhiskies  20.179510  2309.945112  48.061888   0.868258
